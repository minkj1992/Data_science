# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-
import pandas as pd
import numpy as np
train_array = pd.read_csv("/home/minwookje/다운로드/petition.csv",sep=",", header=None,encoding = 'utf8').values
# Out:
# /home/minwookje/anaconda3/envs/keras/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3018: DtypeWarning: Columns (0,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
train = train_array[1:,7]
train = list(train)
print(type(train))
# Out:
# <class 'list'>

# %%
# np.savetxt(,train, fmt='%s')

with open('/home/minwookje/coding/datascience_final_project/word2vec/청원문.txt','w+') as f:
    for item in train:
        f.write("%s\n"% item)
